# %%
from keecas import __version__
from keecas import *

__version__
# Out:
# '0.1.2'

# %%
from typing import Any, List
from sympy import Basic, MatrixBase

tipi = {
    # Any: "any",
    # MatrixBase: "matrix",
    Basic: "basic",
    # List: "list",
}

a = Matrix([[1, 2], [3, 4]])
a = [1, 2, 3]

for t in tipi:
    if isinstance(a, t):
        print(tipi[t])
        break
else:
    print("not found")

from ruamel.yaml import YAML


yaml = YAML()
with open("tipi.yaml", "w") as f:
    yaml.dump(a, f)

import toml

with open("tipi.toml", "w") as f:
    toml.dump(tipi, f)
# Out:
# not found
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[19], line 31
#      28 import toml
#      30 with open("tipi.toml", "w") as f:
# ---> 31     toml.dump(tipi, f)
#
# File ~/github/keecas/.venv/lib/python3.12/site-packages/toml/encoder.py:29, in dump(o, f, encoder)
#      27 if not f.write:
#      28     raise TypeError("You can only dump an object to a file descriptor")
# ---> 29 d = dumps(o, encoder=encoder)
#      30 f.write(d)
#      31 return d
#
# File ~/github/keecas/.venv/lib/python3.12/site-packages/toml/encoder.py:60, in dumps(o, encoder)
#      58 if encoder is None:
#      59     encoder = TomlEncoder(o.__class__)
# ---> 60 addtoretval, sections = encoder.dump_sections(o, "")
#      61 retval += addtoretval
#      62 outer_objs = [id(o)]
#
# ...
